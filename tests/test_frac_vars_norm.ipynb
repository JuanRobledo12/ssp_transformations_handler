# %%
import sys
sys.path.append('..')
from src.ssp_transformations_handler.GeneralUtils import GeneralUtils
import pandas as pd

# %%
# %load_ext autoreload
# %autoreload 2

# %%
df = pd.read_csv('csv/mexico_real_data.csv')
df.head()
# Out:
#   iso_code3  Year  pij_lndu_forests_primary_to_croplands  \
# 0       MEX  2015                               0.000000
# 1       MEX  2016                               0.000000
# 2       MEX  2017                               0.000000
# 3       MEX  2018                               0.000016
# 4       MEX  2019                               0.000031
#
#    pij_lndu_forests_mangroves_to_wetlands  yf_agrc_nuts_tonne_ha  \
# 0                                     0.0               1.497014
# 1                                     0.0               1.438057
# 2                                     0.0               1.435714
# 3                                     0.0               1.464529
# 4                                     0.0               1.452086
#
#    ef_lndu_conv_forests_secondary_to_other_gg_co2_ha  \
# 0                                           0.128343
# 1                                           0.128343
# 2                                           0.128343
# ...

# %%
gu = GeneralUtils()

# %%
gu.normalize_energy_frac_vars(df, 'mapping/energy_frac_vars.xlsx')
# Out:
# Row sums for frac_enfu_fuel_demand are not in range, the sum is 2.2892497593762013. Please check the data.
# Row sums for frac_trns_fuelmix_rail_passenger are not in range, the sum is 2.0. Please check the data.
# /home/tony-ubuntu/decision_sciences/ssp_transformations_handler/tests/../src/ssp_transformations_handler/GeneralUtils.py:203: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.fillna(0)
#    iso_code3  Year  pij_lndu_forests_primary_to_croplands  \
# 0        MEX  2015                               0.000000
# 1        MEX  2016                               0.000000
# 2        MEX  2017                               0.000000
# 3        MEX  2018                               0.000016
# 4        MEX  2019                               0.000031
# ...
